# %% [markdown]
# **Decentralized Tensorflow**
#
# Here is some code for (non-privacy) containing a test model for dencentralized computing. Next steps are to add noise, and scale the size up.

# %% [markdown]
# **Working Version Of Decentralized computing (see below)**
#
# To truly verify it's working good, make sure later to also include ERROR BARS (graph average performance, include min-max performance error bar to show variance). Expected result: Minimum error = Fully connected decentralized, error bar ~ 0 (only source of error is random initilization). Moderate error = Ring network (Not all networks are trained equally, but share some info).MAXIMUM ERROR = individiual network (since al networks have no similarity).
#
#
# Prediction correct! :-) Result: Dense network is similar to fully-connected network, where accuracy is independent of # of nodes, but the less gradients shared, the more dependent the # of nodes is on accuracy (more nodes = less accuracy).
#
# NOTE the bug that fixed this is the apply_gradients, only need to call this ONCE per node trained, or else we're repetitvely doing gradient descent on the same node each time we send the gradient to the sz-1 neighbors.

# %%
#TODO:add more error bars (for all of graphs) 
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data

import matplotlib.pyplot as plt
# %matplotlib inline

mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.log_device_placement = True

#Helper function to swap identities of gradients from one to the other.
def swapIdentity(gradient, newIdentity):
    return (gradient[0], newIdentity) #return new tuple with the identity replaced

def shp(x):
    return np.shape(x) 

#-----------------------Initialization---------------------------
#Hyperparameters:
theta_D = 1 #download rate
theta_U = 0.01 #Upload rate

#sz = 4 # size of network
node_sz = []
accs = []

node_sz_fully = []
accs_fully = []

node_sz_indiv = []
accs_indiv = []
plots = 0

for architecture in range(3): #0 = dense graph N(N-1)/2 connections, #1 = sparse graph (N connections), #3 = independent 
    for sz in range(4,16):
        
        tf.reset_default_graph()

        # Variables for our  4- way network
        W1 = [tf.Variable(tf.truncated_normal([784, 500], stddev=0.1)) for i in range(sz)]
        b1 = [tf.Variable(tf.zeros([500]))                             for i in range(sz)]
        W2 = [tf.Variable(tf.truncated_normal([500, 100], stddev=0.1)) for i in range(sz)]
        b2 = [tf.Variable(tf.zeros([100]))                             for i in range(sz)]
        W3 = [tf.Variable(tf.truncated_normal([100, 10], stddev=0.1))  for i in range(sz)]
        b3 = [tf.Variable(tf.zeros([10]))                              for i in range(sz)]

        #Temporary gradient banks for communication between nodes (noise may be added in future)
        g_W1 = [None for i in range(sz)]
        g_W2 = [None for i in range(sz)]
        g_W3 = [None for i in range(sz)]
        g_b1 = [None for i in range(sz)]
        g_b2 = [None for i in range(sz)]
        g_b3 = [None for i in range(sz)]


        grad_W1 = [[None for i in range(sz)] for i in range(sz)]
        grad_W2 = [[None for i in range(sz)] for i in range(sz)]
        grad_W3 = [[None for i in range(sz)] for i in range(sz)]
        grad_b1 = [[None for i in range(sz)] for i in range(sz)]
        grad_b2 = [[None for i in range(sz)] for i in range(sz)]
        grad_b3 = [[None for i in range(sz)] for i in range(sz)]


        #hidden layers, scores, etc. *Note there is somehow a problem with saying scores = loss = [None for i in range(sz)] so I put them in seperate lines
        h1 = [None for i in range(sz)]
        h2 = [None for i in range(sz)]

        scores = [None for i in range(sz)]
        loss = [None for i in range(sz)]

        #-------------------------Define Decentralized Neural Network Structure-----------------

        # Placeholders
        X = [tf.placeholder(tf.float32, [None, 784])  for i in range(sz)]
        y = [tf.placeholder(tf.float32, [None, 10])    for i in range(sz)]


        # Deep Neural nets for 4 channels w/ loss function
        for i in range(sz):
            h1[i] = tf.nn.relu(tf.matmul(X[i],  W1[i]) + b1[i])
            h2[i] = tf.nn.relu(tf.matmul(h1[i], W2[i]) + b2[i])
            scores[i] = tf.matmul(h2[i], W3[i]) + b3[i]
            loss[i] = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=scores[i], labels=y[i]))

        # Gradient descent for 4 channels
        train_one_step = [None for i in range(sz)]
        opt =[None for i in range(sz)]

        for i in range(sz):
            opt[i] = tf.train.GradientDescentOptimizer(0.05)
            train_one_step[i] = opt[i].minimize(loss[i])



        correct_predictions = [0.0 for i in range(sz)]
        accuracy = [0.0 for i in range(sz)]

        # Accuracy indicator for 4 channels
        for i in range(sz):
            correct_predictions[i] = tf.equal(tf.argmax(scores[i], axis=1), tf.argmax(y[i], axis=1))
            accuracy[i] = tf.reduce_mean(tf.cast(correct_predictions[i], tf.float32))

        # Initialization of all decleared Tensors (above) in Tensorflow
        init = tf.global_variables_initializer()

        # Training
        sess = tf.Session()
        sess.run(init) #initalize all variables

        #Gradient "bank"

        train_acc=[0.0 for i in range(sz)]
        train_loss=[0.0 for i in range(sz)]
        test_acc = [0.0 for i in range(sz)]

        send_gradients = [None for i in range(sz)]

        #-----------------Build the gradients transfer graph---------------------
        for cnode in range(sz):
            #compute local gradients
            g_W1[cnode], g_W2[cnode], g_W3[cnode], g_b1[cnode], g_b2[cnode], g_b3[cnode] = opt[cnode].compute_gradients(
                    loss=loss[cnode], var_list=[W1[cnode], W2[cnode], W3[cnode], b1[cnode], b2[cnode], b3[cnode]])

            #EXperimennt around with either 1)dense, N(N-1)/2 connections, or 2)sparse graph, N connections
            #for nei in range(sz): #Dense graph
            if(architecture == 1):
                neighbors = range(sz)
            elif(architecture == 2):
                neighbors = [(cnode+1) % sz, cnode, (sz + cnode - 1) % sz]
            else:
                neighbors = [cnode]
            
            allgrads = []
            for nei in neighbors:
                #Distribute local gradients from current node to neighboring nodes
                grad_W1[cnode][nei] = swapIdentity(g_W1[cnode], W1[nei])
                grad_W2[cnode][nei] = swapIdentity(g_W2[cnode], W2[nei])
                grad_W3[cnode][nei] = swapIdentity(g_W3[cnode], W3[nei])
                grad_b1[cnode][nei] = swapIdentity(g_b1[cnode], b1[nei])
                grad_b2[cnode][nei] = swapIdentity(g_b2[cnode], b2[nei])
                grad_b3[cnode][nei] = swapIdentity(g_b3[cnode], b3[nei])
                allgrads += [grad_W1[cnode][nei],grad_W2[cnode][nei],grad_W3[cnode][nei],
                             grad_b1[cnode][nei],grad_b2[cnode][nei],grad_b3[cnode][nei]]

            send_gradients[cnode] = opt[cnode].apply_gradients(allgrads)
        #------------------------------Begin Training------------------------------

        #NOTE only for the first node (cnode = 0)
        x_train = []
        y_train = []

        x_test = []
        y_test = []

        #Split data into 4-ths. (50,50,50,50)

        for i in range(2000 // sz):

            for cnode in range(sz):      
                #---------download minibatch of 50 & get gradients-----------------------
                X_batch, y_batch = mnist.train.next_batch(50)

                #send gradients computed from current node to neighbors
                if(architecture == 1):
                    neighbors = range(sz)
                elif(architecture == 2):
                    neighbors = [(cnode+1) % sz, cnode, (sz + cnode - 1) % sz]
                else: #arch = 0: indiviaul
                    neighbors = [cnode]
                    
                for nei in neighbors:
                #for nei in range(sz):
                    sess.run(send_gradients[cnode], feed_dict={X[cnode]: X_batch, y[cnode]: y_batch})



                if(i % 50 == 0):
                    train_acc[cnode] = sess.run(accuracy[cnode], feed_dict={X[cnode]: X_batch, y[cnode]: y_batch})
                    test_acc[cnode] = sess.run(accuracy[cnode], feed_dict={X[cnode]: mnist.test.images, y[cnode]: mnist.test.labels})
                    #PLOT ACCURACY OF FIRST NODE
                    if(cnode == 0):
                        x_train += [i]
                        y_train += [train_acc[cnode]]

                        x_test += [i]
                        y_test += [test_acc[cnode]]
                    print("accuracy for Node: ", cnode,  "  is: ",train_acc[cnode],  "  at epoch: ", i, " test acc: ", test_acc[cnode])

        #after done with training (for i loop), get FINAL test set accuracy for export.
        plots+=1
        plt.figure(plots)
        
        arch = ''
        if(architecture == 1):
            arch = "Dense network"
        elif(architecture == 2):
            arch = "Sparse network"
        else:
            arch = "Independent networks"
        
        plt.title("Number of Nodes: " +str(sz) + " , " + arch)
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.plot(x_train, y_train, 'r', x_test, y_test, 'b')

        maxacc = 0
        # Make sure to print out your accuracy on the test set at the end.
        print("Final accuracy on test set:")
        for i in range(sz):
            accy =  sess.run(accuracy[i], feed_dict={X[i]: mnist.test.images, y[i]: mnist.test.labels})
            print(i, " has accuracy: ",accy)
            maxacc = max(maxacc, accy)
        
        
        if(architecture == 1): #arch = 1: fully
            node_sz_fully += [sz]
            accs_fully += [maxacc]
        elif(architecture == 2): #arch = 2: sparse graph
            node_sz += [sz]
            accs += [maxacc]
        else: #arch = 0: individual
            node_sz_indiv += [sz]
            accs_indiv += [maxacc]

#FINAL PLOT for the #of Agents (Node size) vs. accuracy (max of all agents) 
plt.figure(plots+1)
plt.xlabel('Node size')
plt.ylabel('Accuracy')
#GREEN: sparse results RED: dense results BLUE: individual results
plt.plot(node_sz, accs, 'g', node_sz_fully, accs_fully, 'r', node_sz_indiv, accs_indiv, 'b')
# Out:
# /home/patrick/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/patrick/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# accuracy for Node:  0   is:  0.16   at epoch:  0  test acc:  0.1164
# accuracy for Node:  1   is:  0.22   at epoch:  0  test acc:  0.1152
# accuracy for Node:  2   is:  0.18   at epoch:  0  test acc:  0.0726
# accuracy for Node:  3   is:  0.2   at epoch:  0  test acc:  0.1296
# accuracy for Node:  0   is:  0.88   at epoch:  50  test acc:  0.787
# accuracy for Node:  1   is:  0.84   at epoch:  50  test acc:  0.7886
# accuracy for Node:  2   is:  0.82   at epoch:  50  test acc:  0.7983
# accuracy for Node:  3   is:  0.88   at epoch:  50  test acc:  0.798
# accuracy for Node:  0   is:  0.9   at epoch:  100  test acc:  0.8431
# accuracy for Node:  1   is:  0.92   at epoch:  100  test acc:  0.8526
# accuracy for Node:  2   is:  0.96   at epoch:  100  test acc:  0.8594
# accuracy for Node:  3   is:  0.88   at epoch:  100  test acc:  0.8555
# accuracy for Node:  0   is:  0.9   at epoch:  150  test acc:  0.8562
# accuracy for Node:  1   is:  0.92   at epoch:  150  test acc:  0.878
# accuracy for Node:  2   is:  0.86   at epoch:  150  test acc:  0.8793
# accuracy for Node:  3   is:  0.92   at epoch:  150  test acc:  0.8761
# accuracy for Node:  0   is:  0.92   at epoch:  200  test acc:  0.8905
# accuracy for Node:  1   is:  0.94   at epoch:  200  test acc:  0.8962
# accuracy for Node:  2   is:  1.0   at epoch:  200  test acc:  0.8954
# accuracy for Node:  3   is:  0.94   at epoch:  200  test acc:  0.8848
# accuracy for Node:  0   is:  0.94   at epoch:  250  test acc:  0.8801
# accuracy for Node:  1   is:  0.9   at epoch:  250  test acc:  0.8947
# accuracy for Node:  2   is:  0.94   at epoch:  250  test acc:  0.8971
# accuracy for Node:  3   is:  0.96   at epoch:  250  test acc:  0.8858
# accuracy for Node:  0   is:  0.86   at epoch:  300  test acc:  0.9044
# accuracy for Node:  1   is:  0.88   at epoch:  300  test acc:  0.9004
# accuracy for Node:  2   is:  0.94   at epoch:  300  test acc:  0.9046
# accuracy for Node:  3   is:  0.92   at epoch:  300  test acc:  0.9036
# accuracy for Node:  0   is:  0.9   at epoch:  350  test acc:  0.9032
# accuracy for Node:  1   is:  0.96   at epoch:  350  test acc:  0.9036
# accuracy for Node:  2   is:  0.94   at epoch:  350  test acc:  0.9131
# accuracy for Node:  3   is:  0.92   at epoch:  350  test acc:  0.9076
# accuracy for Node:  0   is:  0.9   at epoch:  400  test acc:  0.9124
# accuracy for Node:  1   is:  0.96   at epoch:  400  test acc:  0.9086
# accuracy for Node:  2   is:  0.94   at epoch:  400  test acc:  0.9071
# accuracy for Node:  3   is:  0.96   at epoch:  400  test acc:  0.9101
# accuracy for Node:  0   is:  0.92   at epoch:  450  test acc:  0.9133
# accuracy for Node:  1   is:  0.98   at epoch:  450  test acc:  0.9159
# accuracy for Node:  2   is:  0.96   at epoch:  450  test acc:  0.9131
# accuracy for Node:  3   is:  0.98   at epoch:  450  test acc:  0.9182
# Final accuracy on test set:
# 0  has accuracy:  0.9175
# 1  has accuracy:  0.9196
# 2  has accuracy:  0.9226
# 3  has accuracy:  0.9225
# accuracy for Node:  0   is:  0.32   at epoch:  0  test acc:  0.1812
# accuracy for Node:  1   is:  0.16   at epoch:  0  test acc:  0.1207
# accuracy for Node:  2   is:  0.26   at epoch:  0  test acc:  0.1507
# accuracy for Node:  3   is:  0.24   at epoch:  0  test acc:  0.1125
# accuracy for Node:  4   is:  0.18   at epoch:  0  test acc:  0.1728
# accuracy for Node:  0   is:  0.86   at epoch:  50  test acc:  0.8129
# accuracy for Node:  1   is:  0.88   at epoch:  50  test acc:  0.8298
# accuracy for Node:  2   is:  0.9   at epoch:  50  test acc:  0.7831
# accuracy for Node:  3   is:  0.92   at epoch:  50  test acc:  0.8163
# accuracy for Node:  4   is:  0.86   at epoch:  50  test acc:  0.7696
# accuracy for Node:  0   is:  0.94   at epoch:  100  test acc:  0.8511
# accuracy for Node:  1   is:  0.9   at epoch:  100  test acc:  0.873
# accuracy for Node:  2   is:  0.9   at epoch:  100  test acc:  0.8458
# accuracy for Node:  3   is:  0.9   at epoch:  100  test acc:  0.8606
# accuracy for Node:  4   is:  0.84   at epoch:  100  test acc:  0.861
# accuracy for Node:  0   is:  0.9   at epoch:  150  test acc:  0.8639
# accuracy for Node:  1   is:  0.98   at epoch:  150  test acc:  0.8828
# accuracy for Node:  2   is:  0.9   at epoch:  150  test acc:  0.8559
# accuracy for Node:  3   is:  0.9   at epoch:  150  test acc:  0.8609
# accuracy for Node:  4   is:  0.82   at epoch:  150  test acc:  0.8854
# accuracy for Node:  0   is:  0.94   at epoch:  200  test acc:  0.8956
# accuracy for Node:  1   is:  0.96   at epoch:  200  test acc:  0.894
# accuracy for Node:  2   is:  0.94   at epoch:  200  test acc:  0.8936
# accuracy for Node:  3   is:  0.98   at epoch:  200  test acc:  0.8892
# accuracy for Node:  4   is:  0.94   at epoch:  200  test acc:  0.895
# accuracy for Node:  0   is:  0.98   at epoch:  250  test acc:  0.8965
# accuracy for Node:  1   is:  0.96   at epoch:  250  test acc:  0.9026
# accuracy for Node:  2   is:  0.96   at epoch:  250  test acc:  0.8995
# accuracy for Node:  3   is:  0.92   at epoch:  250  test acc:  0.9026
# accuracy for Node:  4   is:  0.9   at epoch:  250  test acc:  0.9009
# accuracy for Node:  0   is:  0.96   at epoch:  300  test acc:  0.9002
# accuracy for Node:  1   is:  0.98   at epoch:  300  test acc:  0.9035
# accuracy for Node:  2   is:  0.94   at epoch:  300  test acc:  0.8953
# accuracy for Node:  3   is:  0.94   at epoch:  300  test acc:  0.8571
# accuracy for Node:  4   is:  0.94   at epoch:  300  test acc:  0.9128
# accuracy for Node:  0   is:  0.9   at epoch:  350  test acc:  0.909
# accuracy for Node:  1   is:  0.94   at epoch:  350  test acc:  0.9046
# accuracy for Node:  2   is:  0.96   at epoch:  350  test acc:  0.9078
# accuracy for Node:  3   is:  0.98   at epoch:  350  test acc:  0.9117
# accuracy for Node:  4   is:  0.92   at epoch:  350  test acc:  0.9176
# Final accuracy on test set:
# 0  has accuracy:  0.9056
# 1  has accuracy:  0.917
# 2  has accuracy:  0.913
# 3  has accuracy:  0.9105
# 4  has accuracy:  0.8976
# accuracy for Node:  0   is:  0.2   at epoch:  0  test acc:  0.1401
# accuracy for Node:  1   is:  0.16   at epoch:  0  test acc:  0.1237
# accuracy for Node:  2   is:  0.14   at epoch:  0  test acc:  0.117
# accuracy for Node:  3   is:  0.26   at epoch:  0  test acc:  0.0977
# accuracy for Node:  4   is:  0.3   at epoch:  0  test acc:  0.1315
# accuracy for Node:  5   is:  0.32   at epoch:  0  test acc:  0.1508
# accuracy for Node:  0   is:  0.88   at epoch:  50  test acc:  0.7821
# accuracy for Node:  1   is:  0.8   at epoch:  50  test acc:  0.8139
# accuracy for Node:  2   is:  0.92   at epoch:  50  test acc:  0.7973
# accuracy for Node:  3   is:  0.76   at epoch:  50  test acc:  0.8069
# accuracy for Node:  4   is:  0.84   at epoch:  50  test acc:  0.7787
# accuracy for Node:  5   is:  0.96   at epoch:  50  test acc:  0.7937
# accuracy for Node:  0   is:  0.94   at epoch:  100  test acc:  0.864
# accuracy for Node:  1   is:  0.88   at epoch:  100  test acc:  0.8542
# accuracy for Node:  2   is:  0.86   at epoch:  100  test acc:  0.864
# accuracy for Node:  3   is:  0.88   at epoch:  100  test acc:  0.8528
# accuracy for Node:  4   is:  0.9   at epoch:  100  test acc:  0.8584
# accuracy for Node:  5   is:  0.9   at epoch:  100  test acc:  0.8546
# accuracy for Node:  0   is:  0.86   at epoch:  150  test acc:  0.8787
# accuracy for Node:  1   is:  0.88   at epoch:  150  test acc:  0.8833
# accuracy for Node:  2   is:  0.94   at epoch:  150  test acc:  0.8755
# accuracy for Node:  3   is:  0.88   at epoch:  150  test acc:  0.8693
# accuracy for Node:  4   is:  0.88   at epoch:  150  test acc:  0.8784
# accuracy for Node:  5   is:  0.88   at epoch:  150  test acc:  0.8542
# accuracy for Node:  0   is:  0.96   at epoch:  200  test acc:  0.8981
# accuracy for Node:  1   is:  0.88   at epoch:  200  test acc:  0.8876
# accuracy for Node:  2   is:  0.9   at epoch:  200  test acc:  0.8662
# accuracy for Node:  3   is:  0.9   at epoch:  200  test acc:  0.8828
# accuracy for Node:  4   is:  0.9   at epoch:  200  test acc:  0.8858
# accuracy for Node:  5   is:  0.96   at epoch:  200  test acc:  0.8931
# accuracy for Node:  0   is:  0.9   at epoch:  250  test acc:  0.9013
# accuracy for Node:  1   is:  0.92   at epoch:  250  test acc:  0.8954
# accuracy for Node:  2   is:  0.94   at epoch:  250  test acc:  0.8915
# accuracy for Node:  3   is:  0.88   at epoch:  250  test acc:  0.8954
# accuracy for Node:  4   is:  0.96   at epoch:  250  test acc:  0.895
# accuracy for Node:  5   is:  0.88   at epoch:  250  test acc:  0.8966
# accuracy for Node:  0   is:  0.92   at epoch:  300  test acc:  0.905
# accuracy for Node:  1   is:  0.9   at epoch:  300  test acc:  0.8973
# accuracy for Node:  2   is:  0.92   at epoch:  300  test acc:  0.8994
# accuracy for Node:  3   is:  0.88   at epoch:  300  test acc:  0.9023
# accuracy for Node:  4   is:  0.92   at epoch:  300  test acc:  0.9089
# accuracy for Node:  5   is:  0.92   at epoch:  300  test acc:  0.9016
# Final accuracy on test set:
# 0  has accuracy:  0.8978
# 1  has accuracy:  0.8967
# 2  has accuracy:  0.9008
# 3  has accuracy:  0.9091
# 4  has accuracy:  0.9114
# 5  has accuracy:  0.8641
# accuracy for Node:  0   is:  0.28   at epoch:  0  test acc:  0.1494
# accuracy for Node:  1   is:  0.14   at epoch:  0  test acc:  0.117
# accuracy for Node:  2   is:  0.22   at epoch:  0  test acc:  0.1227
# accuracy for Node:  3   is:  0.14   at epoch:  0  test acc:  0.0978
# accuracy for Node:  4   is:  0.24   at epoch:  0  test acc:  0.1354
# accuracy for Node:  5   is:  0.26   at epoch:  0  test acc:  0.1979
# accuracy for Node:  6   is:  0.14   at epoch:  0  test acc:  0.1064
# accuracy for Node:  0   is:  0.86   at epoch:  50  test acc:  0.7724
# accuracy for Node:  1   is:  0.86   at epoch:  50  test acc:  0.8066
# accuracy for Node:  2   is:  0.8   at epoch:  50  test acc:  0.8017
# accuracy for Node:  3   is:  0.8   at epoch:  50  test acc:  0.7629
# accuracy for Node:  4   is:  0.88   at epoch:  50  test acc:  0.7947
# accuracy for Node:  5   is:  0.86   at epoch:  50  test acc:  0.8037
# accuracy for Node:  6   is:  0.9   at epoch:  50  test acc:  0.8042
# accuracy for Node:  0   is:  0.84   at epoch:  100  test acc:  0.8538
# accuracy for Node:  1   is:  0.84   at epoch:  100  test acc:  0.8447
# accuracy for Node:  2   is:  0.9   at epoch:  100  test acc:  0.867
# accuracy for Node:  3   is:  0.98   at epoch:  100  test acc:  0.8435
# accuracy for Node:  4   is:  0.82   at epoch:  100  test acc:  0.8436
# accuracy for Node:  5   is:  0.92   at epoch:  100  test acc:  0.853
# accuracy for Node:  6   is:  0.9   at epoch:  100  test acc:  0.8605
# accuracy for Node:  0   is:  0.88   at epoch:  150  test acc:  0.8791
# accuracy for Node:  1   is:  0.96   at epoch:  150  test acc:  0.8792
# accuracy for Node:  2   is:  0.98   at epoch:  150  test acc:  0.8862
# accuracy for Node:  3   is:  0.82   at epoch:  150  test acc:  0.8851
# accuracy for Node:  4   is:  0.94   at epoch:  150  test acc:  0.8749
# accuracy for Node:  5   is:  0.96   at epoch:  150  test acc:  0.8792
# accuracy for Node:  6   is:  0.94   at epoch:  150  test acc:  0.8747
# accuracy for Node:  0   is:  0.98   at epoch:  200  test acc:  0.8847
# accuracy for Node:  1   is:  0.98   at epoch:  200  test acc:  0.8935
# accuracy for Node:  2   is:  0.98   at epoch:  200  test acc:  0.8857
# accuracy for Node:  3   is:  1.0   at epoch:  200  test acc:  0.8823
# accuracy for Node:  4   is:  0.88   at epoch:  200  test acc:  0.8927
# accuracy for Node:  5   is:  0.9   at epoch:  200  test acc:  0.8913
# accuracy for Node:  6   is:  0.88   at epoch:  200  test acc:  0.8848
# accuracy for Node:  0   is:  0.94   at epoch:  250  test acc:  0.8903
# accuracy for Node:  1   is:  0.96   at epoch:  250  test acc:  0.9041
# accuracy for Node:  2   is:  0.88   at epoch:  250  test acc:  0.8867
# accuracy for Node:  3   is:  0.9   at epoch:  250  test acc:  0.8992
# accuracy for Node:  4   is:  0.92   at epoch:  250  test acc:  0.8987
# accuracy for Node:  5   is:  1.0   at epoch:  250  test acc:  0.9017
# accuracy for Node:  6   is:  0.98   at epoch:  250  test acc:  0.8959
# Final accuracy on test set:
# 0  has accuracy:  0.8973
# 1  has accuracy:  0.9077
# 2  has accuracy:  0.9056
# 3  has accuracy:  0.9083
# 4  has accuracy:  0.9054
# 5  has accuracy:  0.903
# 6  has accuracy:  0.9003
# accuracy for Node:  0   is:  0.3   at epoch:  0  test acc:  0.1281
# accuracy for Node:  1   is:  0.26   at epoch:  0  test acc:  0.137
# accuracy for Node:  2   is:  0.22   at epoch:  0  test acc:  0.1306
# accuracy for Node:  3   is:  0.22   at epoch:  0  test acc:  0.139
# accuracy for Node:  4   is:  0.14   at epoch:  0  test acc:  0.0875
# accuracy for Node:  5   is:  0.22   at epoch:  0  test acc:  0.1129
# accuracy for Node:  6   is:  0.3   at epoch:  0  test acc:  0.1983
# accuracy for Node:  7   is:  0.22   at epoch:  0  test acc:  0.1459
# accuracy for Node:  0   is:  0.86   at epoch:  50  test acc:  0.7959
# accuracy for Node:  1   is:  0.82   at epoch:  50  test acc:  0.7458
# accuracy for Node:  2   is:  0.92   at epoch:  50  test acc:  0.799
# accuracy for Node:  3   is:  0.82   at epoch:  50  test acc:  0.7976
# accuracy for Node:  4   is:  0.84   at epoch:  50  test acc:  0.8161
# accuracy for Node:  5   is:  0.76   at epoch:  50  test acc:  0.7973
# accuracy for Node:  6   is:  0.86   at epoch:  50  test acc:  0.8089
# accuracy for Node:  7   is:  0.76   at epoch:  50  test acc:  0.8024
# accuracy for Node:  0   is:  0.92   at epoch:  100  test acc:  0.8379
# accuracy for Node:  1   is:  0.86   at epoch:  100  test acc:  0.8588
# accuracy for Node:  2   is:  0.96   at epoch:  100  test acc:  0.8272
# accuracy for Node:  3   is:  0.94   at epoch:  100  test acc:  0.8611
# accuracy for Node:  4   is:  0.92   at epoch:  100  test acc:  0.8342
# accuracy for Node:  5   is:  0.88   at epoch:  100  test acc:  0.8522
# accuracy for Node:  6   is:  0.98   at epoch:  100  test acc:  0.8591
# accuracy for Node:  7   is:  0.92   at epoch:  100  test acc:  0.8403
# accuracy for Node:  0   is:  0.94   at epoch:  150  test acc:  0.8883
# accuracy for Node:  1   is:  0.9   at epoch:  150  test acc:  0.8825
# accuracy for Node:  2   is:  0.84   at epoch:  150  test acc:  0.8615
# accuracy for Node:  3   is:  0.94   at epoch:  150  test acc:  0.8859
# accuracy for Node:  4   is:  0.92   at epoch:  150  test acc:  0.8785
# accuracy for Node:  5   is:  0.9   at epoch:  150  test acc:  0.8795
# accuracy for Node:  6   is:  0.92   at epoch:  150  test acc:  0.8883
# accuracy for Node:  7   is:  0.9   at epoch:  150  test acc:  0.8911
# accuracy for Node:  0   is:  0.86   at epoch:  200  test acc:  0.8975
# accuracy for Node:  1   is:  0.92   at epoch:  200  test acc:  0.8982
# accuracy for Node:  2   is:  0.9   at epoch:  200  test acc:  0.8875
# accuracy for Node:  3   is:  0.96   at epoch:  200  test acc:  0.8661
# accuracy for Node:  4   is:  0.94   at epoch:  200  test acc:  0.8932
# accuracy for Node:  5   is:  0.98   at epoch:  200  test acc:  0.8856
# accuracy for Node:  6   is:  0.92   at epoch:  200  test acc:  0.8892
# accuracy for Node:  7   is:  0.9   at epoch:  200  test acc:  0.8884
# Final accuracy on test set:
# 0  has accuracy:  0.9045
# 1  has accuracy:  0.9046
# 2  has accuracy:  0.8955
# 3  has accuracy:  0.9036
# 4  has accuracy:  0.9052
# 5  has accuracy:  0.9041
# 6  has accuracy:  0.8959
# 7  has accuracy:  0.8995
# accuracy for Node:  0   is:  0.16   at epoch:  0  test acc:  0.121
# accuracy for Node:  1   is:  0.32   at epoch:  0  test acc:  0.1795
# accuracy for Node:  2   is:  0.2   at epoch:  0  test acc:  0.128
# accuracy for Node:  3   is:  0.22   at epoch:  0  test acc:  0.1281
# accuracy for Node:  4   is:  0.24   at epoch:  0  test acc:  0.1434
# accuracy for Node:  5   is:  0.22   at epoch:  0  test acc:  0.1208
# accuracy for Node:  6   is:  0.24   at epoch:  0  test acc:  0.1394
# accuracy for Node:  7   is:  0.2   at epoch:  0  test acc:  0.158
# accuracy for Node:  8   is:  0.16   at epoch:  0  test acc:  0.1295
# accuracy for Node:  0   is:  0.8   at epoch:  50  test acc:  0.8059
# accuracy for Node:  1   is:  0.82   at epoch:  50  test acc:  0.7784
# accuracy for Node:  2   is:  0.86   at epoch:  50  test acc:  0.8091
# accuracy for Node:  3   is:  0.8   at epoch:  50  test acc:  0.8015
# accuracy for Node:  4   is:  0.88   at epoch:  50  test acc:  0.7848
# accuracy for Node:  5   is:  0.9   at epoch:  50  test acc:  0.796
# accuracy for Node:  6   is:  0.8   at epoch:  50  test acc:  0.8017
# accuracy for Node:  7   is:  0.88   at epoch:  50  test acc:  0.8044
# accuracy for Node:  8   is:  0.84   at epoch:  50  test acc:  0.7724
# accuracy for Node:  0   is:  0.96   at epoch:  100  test acc:  0.8355
# accuracy for Node:  1   is:  0.9   at epoch:  100  test acc:  0.848
# accuracy for Node:  2   is:  0.92   at epoch:  100  test acc:  0.8731
# accuracy for Node:  3   is:  0.9   at epoch:  100  test acc:  0.8584
# accuracy for Node:  4   is:  0.88   at epoch:  100  test acc:  0.8479
# accuracy for Node:  5   is:  0.94   at epoch:  100  test acc:  0.8476
# accuracy for Node:  6   is:  1.0   at epoch:  100  test acc:  0.8596
# accuracy for Node:  7   is:  0.9   at epoch:  100  test acc:  0.8536
# accuracy for Node:  8   is:  0.88   at epoch:  100  test acc:  0.856
# accuracy for Node:  0   is:  0.9   at epoch:  150  test acc:  0.8816
# accuracy for Node:  1   is:  0.96   at epoch:  150  test acc:  0.88
# accuracy for Node:  2   is:  0.9   at epoch:  150  test acc:  0.8865
# accuracy for Node:  3   is:  0.94   at epoch:  150  test acc:  0.8779
# accuracy for Node:  4   is:  0.88   at epoch:  150  test acc:  0.8808
# accuracy for Node:  5   is:  0.92   at epoch:  150  test acc:  0.8749
# accuracy for Node:  6   is:  0.92   at epoch:  150  test acc:  0.8782
# accuracy for Node:  7   is:  0.96   at epoch:  150  test acc:  0.8795
# accuracy for Node:  8   is:  0.96   at epoch:  150  test acc:  0.8845
# accuracy for Node:  0   is:  0.92   at epoch:  200  test acc:  0.8974
# accuracy for Node:  1   is:  0.96   at epoch:  200  test acc:  0.8915
# accuracy for Node:  2   is:  0.9   at epoch:  200  test acc:  0.8746
# accuracy for Node:  3   is:  0.94   at epoch:  200  test acc:  0.8944
# accuracy for Node:  4   is:  0.94   at epoch:  200  test acc:  0.8785
# accuracy for Node:  5   is:  0.88   at epoch:  200  test acc:  0.8932
# accuracy for Node:  6   is:  0.98   at epoch:  200  test acc:  0.891
# accuracy for Node:  7   is:  0.98   at epoch:  200  test acc:  0.8882
# accuracy for Node:  8   is:  0.92   at epoch:  200  test acc:  0.8869
# Final accuracy on test set:
# 0  has accuracy:  0.9019
# 1  has accuracy:  0.8882
# 2  has accuracy:  0.8986
# 3  has accuracy:  0.8954
# 4  has accuracy:  0.8937
# 5  has accuracy:  0.8951
# 6  has accuracy:  0.8859
# 7  has accuracy:  0.8985
# 8  has accuracy:  0.8933
# accuracy for Node:  0   is:  0.24   at epoch:  0  test acc:  0.1756
# accuracy for Node:  1   is:  0.1   at epoch:  0  test acc:  0.0849
# accuracy for Node:  2   is:  0.22   at epoch:  0  test acc:  0.1446
# accuracy for Node:  3   is:  0.16   at epoch:  0  test acc:  0.13
# accuracy for Node:  4   is:  0.16   at epoch:  0  test acc:  0.1241
# accuracy for Node:  5   is:  0.18   at epoch:  0  test acc:  0.1416
# accuracy for Node:  6   is:  0.12   at epoch:  0  test acc:  0.1371
# accuracy for Node:  7   is:  0.2   at epoch:  0  test acc:  0.1343
# accuracy for Node:  8   is:  0.16   at epoch:  0  test acc:  0.1468
# accuracy for Node:  9   is:  0.22   at epoch:  0  test acc:  0.1441
# accuracy for Node:  0   is:  0.9   at epoch:  50  test acc:  0.7916
# accuracy for Node:  1   is:  0.84   at epoch:  50  test acc:  0.7781
# accuracy for Node:  2   is:  0.84   at epoch:  50  test acc:  0.8071
# accuracy for Node:  3   is:  0.8   at epoch:  50  test acc:  0.7719
# accuracy for Node:  4   is:  0.92   at epoch:  50  test acc:  0.7976
# accuracy for Node:  5   is:  0.82   at epoch:  50  test acc:  0.783
# accuracy for Node:  6   is:  0.82   at epoch:  50  test acc:  0.7828
# accuracy for Node:  7   is:  0.94   at epoch:  50  test acc:  0.796
# accuracy for Node:  8   is:  0.96   at epoch:  50  test acc:  0.8194
# accuracy for Node:  9   is:  0.82   at epoch:  50  test acc:  0.8037
# accuracy for Node:  0   is:  0.92   at epoch:  100  test acc:  0.8558
# accuracy for Node:  1   is:  0.94   at epoch:  100  test acc:  0.8511
# accuracy for Node:  2   is:  0.92   at epoch:  100  test acc:  0.855
# accuracy for Node:  3   is:  0.84   at epoch:  100  test acc:  0.8484
# accuracy for Node:  4   is:  0.9   at epoch:  100  test acc:  0.8461
# accuracy for Node:  5   is:  0.92   at epoch:  100  test acc:  0.861
# accuracy for Node:  6   is:  0.88   at epoch:  100  test acc:  0.8588
# accuracy for Node:  7   is:  0.92   at epoch:  100  test acc:  0.8527
# accuracy for Node:  8   is:  0.94   at epoch:  100  test acc:  0.8493
# accuracy for Node:  9   is:  0.86   at epoch:  100  test acc:  0.854
# accuracy for Node:  0   is:  0.92   at epoch:  150  test acc:  0.8689
# accuracy for Node:  1   is:  0.92   at epoch:  150  test acc:  0.8729
# accuracy for Node:  2   is:  0.88   at epoch:  150  test acc:  0.87
# accuracy for Node:  3   is:  0.98   at epoch:  150  test acc:  0.8818
# accuracy for Node:  4   is:  0.98   at epoch:  150  test acc:  0.8823
# accuracy for Node:  5   is:  0.98   at epoch:  150  test acc:  0.8776
# accuracy for Node:  6   is:  0.9   at epoch:  150  test acc:  0.8698
# accuracy for Node:  7   is:  0.88   at epoch:  150  test acc:  0.8848
# accuracy for Node:  8   is:  0.86   at epoch:  150  test acc:  0.8818
# accuracy for Node:  9   is:  0.92   at epoch:  150  test acc:  0.8733
# Final accuracy on test set:
# 0  has accuracy:  0.8943
# 1  has accuracy:  0.874
# 2  has accuracy:  0.8892
# 3  has accuracy:  0.8878
# 4  has accuracy:  0.886
# 5  has accuracy:  0.8873
# 6  has accuracy:  0.8945
# 7  has accuracy:  0.8892
# 8  has accuracy:  0.8876
# 9  has accuracy:  0.881
# accuracy for Node:  0   is:  0.1   at epoch:  0  test acc:  0.1014
# accuracy for Node:  1   is:  0.12   at epoch:  0  test acc:  0.0938
# accuracy for Node:  2   is:  0.28   at epoch:  0  test acc:  0.1097
# accuracy for Node:  3   is:  0.3   at epoch:  0  test acc:  0.1326
# accuracy for Node:  4   is:  0.28   at epoch:  0  test acc:  0.1527
# accuracy for Node:  5   is:  0.32   at epoch:  0  test acc:  0.1624
# accuracy for Node:  6   is:  0.18   at epoch:  0  test acc:  0.0945
# accuracy for Node:  7   is:  0.32   at epoch:  0  test acc:  0.1626
# accuracy for Node:  8   is:  0.3   at epoch:  0  test acc:  0.1179
# accuracy for Node:  9   is:  0.3   at epoch:  0  test acc:  0.1638
# accuracy for Node:  10   is:  0.34   at epoch:  0  test acc:  0.1822
# accuracy for Node:  0   is:  0.8   at epoch:  50  test acc:  0.8082
# accuracy for Node:  1   is:  0.92   at epoch:  50  test acc:  0.8128
# accuracy for Node:  2   is:  0.94   at epoch:  50  test acc:  0.8047
# accuracy for Node:  3   is:  0.9   at epoch:  50  test acc:  0.7884
# accuracy for Node:  4   is:  0.84   at epoch:  50  test acc:  0.7947
# accuracy for Node:  5   is:  0.86   at epoch:  50  test acc:  0.8159
# accuracy for Node:  6   is:  0.86   at epoch:  50  test acc:  0.8053
# accuracy for Node:  7   is:  0.88   at epoch:  50  test acc:  0.8085
# accuracy for Node:  8   is:  0.84   at epoch:  50  test acc:  0.7629
# accuracy for Node:  9   is:  0.82   at epoch:  50  test acc:  0.8018
# accuracy for Node:  10   is:  0.82   at epoch:  50  test acc:  0.8069
# accuracy for Node:  0   is:  0.86   at epoch:  100  test acc:  0.8345
# accuracy for Node:  1   is:  0.94   at epoch:  100  test acc:  0.8273
# accuracy for Node:  2   is:  0.88   at epoch:  100  test acc:  0.8597
# accuracy for Node:  3   is:  0.94   at epoch:  100  test acc:  0.846
# accuracy for Node:  4   is:  0.82   at epoch:  100  test acc:  0.8602
# accuracy for Node:  5   is:  0.88   at epoch:  100  test acc:  0.865
# accuracy for Node:  6   is:  0.84   at epoch:  100  test acc:  0.8427
# accuracy for Node:  7   is:  0.96   at epoch:  100  test acc:  0.8695
# accuracy for Node:  8   is:  0.88   at epoch:  100  test acc:  0.8424
# accuracy for Node:  9   is:  0.94   at epoch:  100  test acc:  0.8475
# accuracy for Node:  10   is:  0.94   at epoch:  100  test acc:  0.8404
# accuracy for Node:  0   is:  0.94   at epoch:  150  test acc:  0.8608
# accuracy for Node:  1   is:  0.86   at epoch:  150  test acc:  0.8782
# accuracy for Node:  2   is:  0.88   at epoch:  150  test acc:  0.8652
# accuracy for Node:  3   is:  0.94   at epoch:  150  test acc:  0.8728
# accuracy for Node:  4   is:  0.94   at epoch:  150  test acc:  0.8814
# accuracy for Node:  5   is:  0.98   at epoch:  150  test acc:  0.8772
# accuracy for Node:  6   is:  0.9   at epoch:  150  test acc:  0.8761
# accuracy for Node:  7   is:  0.96   at epoch:  150  test acc:  0.8683
# accuracy for Node:  8   is:  0.96   at epoch:  150  test acc:  0.8765
# accuracy for Node:  9   is:  0.88   at epoch:  150  test acc:  0.8799
# accuracy for Node:  10   is:  0.94   at epoch:  150  test acc:  0.8837
# Final accuracy on test set:
# 0  has accuracy:  0.8833
# 1  has accuracy:  0.8873
# 2  has accuracy:  0.8931
# 3  has accuracy:  0.886
# 4  has accuracy:  0.8782
# 5  has accuracy:  0.8936
# 6  has accuracy:  0.8829
# 7  has accuracy:  0.8889
# 8  has accuracy:  0.8842
# 9  has accuracy:  0.8896
# 10  has accuracy:  0.8888
# accuracy for Node:  0   is:  0.24   at epoch:  0  test acc:  0.1296
# accuracy for Node:  1   is:  0.18   at epoch:  0  test acc:  0.0866
# accuracy for Node:  2   is:  0.26   at epoch:  0  test acc:  0.151
# accuracy for Node:  3   is:  0.28   at epoch:  0  test acc:  0.1012
# accuracy for Node:  4   is:  0.24   at epoch:  0  test acc:  0.1392
# accuracy for Node:  5   is:  0.16   at epoch:  0  test acc:  0.138
# accuracy for Node:  6   is:  0.34   at epoch:  0  test acc:  0.1551
# accuracy for Node:  7   is:  0.22   at epoch:  0  test acc:  0.1433
# accuracy for Node:  8   is:  0.3   at epoch:  0  test acc:  0.1936
# accuracy for Node:  9   is:  0.28   at epoch:  0  test acc:  0.1559
# accuracy for Node:  10   is:  0.14   at epoch:  0  test acc:  0.1145
# accuracy for Node:  11   is:  0.26   at epoch:  0  test acc:  0.1136
# accuracy for Node:  0   is:  0.84   at epoch:  50  test acc:  0.7866
# accuracy for Node:  1   is:  0.82   at epoch:  50  test acc:  0.8109
# accuracy for Node:  2   is:  0.88   at epoch:  50  test acc:  0.8094
# accuracy for Node:  3   is:  0.86   at epoch:  50  test acc:  0.8145
# accuracy for Node:  4   is:  0.9   at epoch:  50  test acc:  0.8039
# accuracy for Node:  5   is:  0.88   at epoch:  50  test acc:  0.7655
# accuracy for Node:  6   is:  0.94   at epoch:  50  test acc:  0.7914
# accuracy for Node:  7   is:  0.8   at epoch:  50  test acc:  0.8123
# accuracy for Node:  8   is:  0.8   at epoch:  50  test acc:  0.825
# accuracy for Node:  9   is:  0.88   at epoch:  50  test acc:  0.7957
# accuracy for Node:  10   is:  0.86   at epoch:  50  test acc:  0.8044
# accuracy for Node:  11   is:  0.88   at epoch:  50  test acc:  0.7667
# accuracy for Node:  0   is:  0.92   at epoch:  100  test acc:  0.8652
# accuracy for Node:  1   is:  0.76   at epoch:  100  test acc:  0.8579
# accuracy for Node:  2   is:  0.94   at epoch:  100  test acc:  0.865
# accuracy for Node:  3   is:  0.96   at epoch:  100  test acc:  0.8551
# accuracy for Node:  4   is:  0.84   at epoch:  100  test acc:  0.856
# accuracy for Node:  5   is:  0.9   at epoch:  100  test acc:  0.8395
# accuracy for Node:  6   is:  0.96   at epoch:  100  test acc:  0.8211
# accuracy for Node:  7   is:  0.96   at epoch:  100  test acc:  0.8668
# accuracy for Node:  8   is:  0.86   at epoch:  100  test acc:  0.8648
# accuracy for Node:  9   is:  0.9   at epoch:  100  test acc:  0.8439
# accuracy for Node:  10   is:  0.88   at epoch:  100  test acc:  0.8562
# accuracy for Node:  11   is:  0.9   at epoch:  100  test acc:  0.8519
# accuracy for Node:  0   is:  0.88   at epoch:  150  test acc:  0.8763
# accuracy for Node:  1   is:  0.92   at epoch:  150  test acc:  0.858
# accuracy for Node:  2   is:  0.9   at epoch:  150  test acc:  0.8833
# accuracy for Node:  3   is:  0.94   at epoch:  150  test acc:  0.8874
# accuracy for Node:  4   is:  0.9   at epoch:  150  test acc:  0.877
# accuracy for Node:  5   is:  0.9   at epoch:  150  test acc:  0.8718
# accuracy for Node:  6   is:  0.98   at epoch:  150  test acc:  0.8808
# accuracy for Node:  7   is:  0.94   at epoch:  150  test acc:  0.886
# accuracy for Node:  8   is:  0.9   at epoch:  150  test acc:  0.8921
# accuracy for Node:  9   is:  0.92   at epoch:  150  test acc:  0.8824
# accuracy for Node:  10   is:  0.92   at epoch:  150  test acc:  0.8703
# accuracy for Node:  11   is:  0.86   at epoch:  150  test acc:  0.8648
# Final accuracy on test set:
# 0  has accuracy:  0.8784
# 1  has accuracy:  0.8907
# 2  has accuracy:  0.8834
# 3  has accuracy:  0.8803
# 4  has accuracy:  0.8797
# 5  has accuracy:  0.8772
# 6  has accuracy:  0.8726
# 7  has accuracy:  0.8823
# 8  has accuracy:  0.8871
# 9  has accuracy:  0.8799
# 10  has accuracy:  0.8693
# 11  has accuracy:  0.8918
# accuracy for Node:  0   is:  0.22   at epoch:  0  test acc:  0.1582
# accuracy for Node:  1   is:  0.1   at epoch:  0  test acc:  0.0906
# accuracy for Node:  2   is:  0.14   at epoch:  0  test acc:  0.0929
# accuracy for Node:  3   is:  0.18   at epoch:  0  test acc:  0.1074
# accuracy for Node:  4   is:  0.14   at epoch:  0  test acc:  0.1266
# accuracy for Node:  5   is:  0.36   at epoch:  0  test acc:  0.1581
# accuracy for Node:  6   is:  0.36   at epoch:  0  test acc:  0.1424
# accuracy for Node:  7   is:  0.34   at epoch:  0  test acc:  0.1531
# accuracy for Node:  8   is:  0.24   at epoch:  0  test acc:  0.1374
# accuracy for Node:  9   is:  0.32   at epoch:  0  test acc:  0.1094
# accuracy for Node:  10   is:  0.14   at epoch:  0  test acc:  0.1065
# accuracy for Node:  11   is:  0.2   at epoch:  0  test acc:  0.1084
# accuracy for Node:  12   is:  0.22   at epoch:  0  test acc:  0.1342
# accuracy for Node:  0   is:  0.88   at epoch:  50  test acc:  0.774
# accuracy for Node:  1   is:  0.82   at epoch:  50  test acc:  0.8032
# accuracy for Node:  2   is:  0.88   at epoch:  50  test acc:  0.8013
# accuracy for Node:  3   is:  0.84   at epoch:  50  test acc:  0.7909
# accuracy for Node:  4   is:  0.88   at epoch:  50  test acc:  0.7914
# accuracy for Node:  5   is:  0.84   at epoch:  50  test acc:  0.7873
# accuracy for Node:  6   is:  0.9   at epoch:  50  test acc:  0.7848
# accuracy for Node:  7   is:  0.84   at epoch:  50  test acc:  0.7929
# accuracy for Node:  8   is:  0.84   at epoch:  50  test acc:  0.7889
# accuracy for Node:  9   is:  0.88   at epoch:  50  test acc:  0.7582
# accuracy for Node:  10   is:  0.84   at epoch:  50  test acc:  0.7934
# accuracy for Node:  11   is:  0.86   at epoch:  50  test acc:  0.7717
# accuracy for Node:  12   is:  0.88   at epoch:  50  test acc:  0.7832
# accuracy for Node:  0   is:  0.9   at epoch:  100  test acc:  0.8446
# accuracy for Node:  1   is:  0.92   at epoch:  100  test acc:  0.8361
# accuracy for Node:  2   is:  0.92   at epoch:  100  test acc:  0.8625
# accuracy for Node:  3   is:  0.88   at epoch:  100  test acc:  0.8705
# accuracy for Node:  4   is:  0.88   at epoch:  100  test acc:  0.8508
# accuracy for Node:  5   is:  0.92   at epoch:  100  test acc:  0.8586
# accuracy for Node:  6   is:  0.94   at epoch:  100  test acc:  0.8315
# accuracy for Node:  7   is:  0.84   at epoch:  100  test acc:  0.845
# accuracy for Node:  8   is:  0.82   at epoch:  100  test acc:  0.8509
# accuracy for Node:  9   is:  0.92   at epoch:  100  test acc:  0.8238
# accuracy for Node:  10   is:  0.96   at epoch:  100  test acc:  0.8573
# accuracy for Node:  11   is:  0.96   at epoch:  100  test acc:  0.8605
# accuracy for Node:  12   is:  0.88   at epoch:  100  test acc:  0.8243
# accuracy for Node:  0   is:  0.9   at epoch:  150  test acc:  0.8748
# accuracy for Node:  1   is:  0.92   at epoch:  150  test acc:  0.8802
# accuracy for Node:  2   is:  0.96   at epoch:  150  test acc:  0.874
# accuracy for Node:  3   is:  0.96   at epoch:  150  test acc:  0.8881
# accuracy for Node:  4   is:  1.0   at epoch:  150  test acc:  0.874
# accuracy for Node:  5   is:  0.98   at epoch:  150  test acc:  0.8667
# accuracy for Node:  6   is:  0.84   at epoch:  150  test acc:  0.8635
# accuracy for Node:  7   is:  0.94   at epoch:  150  test acc:  0.8749
# accuracy for Node:  8   is:  0.98   at epoch:  150  test acc:  0.8854
# accuracy for Node:  9   is:  0.96   at epoch:  150  test acc:  0.8751
# accuracy for Node:  10   is:  1.0   at epoch:  150  test acc:  0.8857
# accuracy for Node:  11   is:  0.86   at epoch:  150  test acc:  0.8866
# accuracy for Node:  12   is:  0.94   at epoch:  150  test acc:  0.8821
# Final accuracy on test set:
# 0  has accuracy:  0.8768
# 1  has accuracy:  0.8782
# 2  has accuracy:  0.864
# 3  has accuracy:  0.8855
# 4  has accuracy:  0.878
# 5  has accuracy:  0.8566
# 6  has accuracy:  0.8639
# 7  has accuracy:  0.8829
# 8  has accuracy:  0.8849
# 9  has accuracy:  0.8711
# 10  has accuracy:  0.884
# 11  has accuracy:  0.8863
# 12  has accuracy:  0.8738
# accuracy for Node:  0   is:  0.22   at epoch:  0  test acc:  0.1361
# accuracy for Node:  1   is:  0.12   at epoch:  0  test acc:  0.1038
# accuracy for Node:  2   is:  0.2   at epoch:  0  test acc:  0.1362
# accuracy for Node:  3   is:  0.2   at epoch:  0  test acc:  0.1031
# accuracy for Node:  4   is:  0.2   at epoch:  0  test acc:  0.1241
# accuracy for Node:  5   is:  0.2   at epoch:  0  test acc:  0.1568
# accuracy for Node:  6   is:  0.3   at epoch:  0  test acc:  0.159
# accuracy for Node:  7   is:  0.26   at epoch:  0  test acc:  0.1181
# accuracy for Node:  8   is:  0.24   at epoch:  0  test acc:  0.0803
# accuracy for Node:  9   is:  0.1   at epoch:  0  test acc:  0.0692
# accuracy for Node:  10   is:  0.24   at epoch:  0  test acc:  0.1197
# accuracy for Node:  11   is:  0.2   at epoch:  0  test acc:  0.0934
# accuracy for Node:  12   is:  0.28   at epoch:  0  test acc:  0.1368
# accuracy for Node:  13   is:  0.14   at epoch:  0  test acc:  0.085
# accuracy for Node:  0   is:  0.78   at epoch:  50  test acc:  0.7964
# accuracy for Node:  1   is:  0.8   at epoch:  50  test acc:  0.7833
# accuracy for Node:  2   is:  0.88   at epoch:  50  test acc:  0.7852
# accuracy for Node:  3   is:  0.88   at epoch:  50  test acc:  0.8163
# accuracy for Node:  4   is:  0.9   at epoch:  50  test acc:  0.7991
# accuracy for Node:  5   is:  0.86   at epoch:  50  test acc:  0.7889
# accuracy for Node:  6   is:  0.78   at epoch:  50  test acc:  0.8229
# accuracy for Node:  7   is:  0.9   at epoch:  50  test acc:  0.8258
# accuracy for Node:  8   is:  0.86   at epoch:  50  test acc:  0.7983
# accuracy for Node:  9   is:  0.94   at epoch:  50  test acc:  0.8108
# accuracy for Node:  10   is:  0.78   at epoch:  50  test acc:  0.8052
# accuracy for Node:  11   is:  0.86   at epoch:  50  test acc:  0.8151
# accuracy for Node:  12   is:  0.88   at epoch:  50  test acc:  0.7974
# accuracy for Node:  13   is:  0.88   at epoch:  50  test acc:  0.8038
# accuracy for Node:  0   is:  0.94   at epoch:  100  test acc:  0.8181
# accuracy for Node:  1   is:  0.92   at epoch:  100  test acc:  0.8565
# accuracy for Node:  2   is:  0.88   at epoch:  100  test acc:  0.8518
# accuracy for Node:  3   is:  0.9   at epoch:  100  test acc:  0.8454
# accuracy for Node:  4   is:  0.92   at epoch:  100  test acc:  0.8596
# accuracy for Node:  5   is:  0.9   at epoch:  100  test acc:  0.8502
# accuracy for Node:  6   is:  0.94   at epoch:  100  test acc:  0.8526
# accuracy for Node:  7   is:  0.92   at epoch:  100  test acc:  0.8154
# accuracy for Node:  8   is:  0.84   at epoch:  100  test acc:  0.861
# accuracy for Node:  9   is:  0.9   at epoch:  100  test acc:  0.8528
# accuracy for Node:  10   is:  0.92   at epoch:  100  test acc:  0.8499
# accuracy for Node:  11   is:  0.92   at epoch:  100  test acc:  0.8305
# accuracy for Node:  12   is:  0.86   at epoch:  100  test acc:  0.8628
# accuracy for Node:  13   is:  0.92   at epoch:  100  test acc:  0.8441
# Final accuracy on test set:
# 0  has accuracy:  0.8644
# 1  has accuracy:  0.8687
# 2  has accuracy:  0.8739
# 3  has accuracy:  0.8785
# 4  has accuracy:  0.881
# 5  has accuracy:  0.8811
# 6  has accuracy:  0.8637
# 7  has accuracy:  0.8727
# 8  has accuracy:  0.8747
# 9  has accuracy:  0.8756
# 10  has accuracy:  0.8888
# 11  has accuracy:  0.8798
# 12  has accuracy:  0.8832
# 13  has accuracy:  0.8839
# accuracy for Node:  0   is:  0.2   at epoch:  0  test acc:  0.1168
# accuracy for Node:  1   is:  0.08   at epoch:  0  test acc:  0.091
# accuracy for Node:  2   is:  0.22   at epoch:  0  test acc:  0.1066
# accuracy for Node:  3   is:  0.28   at epoch:  0  test acc:  0.1491
# accuracy for Node:  4   is:  0.26   at epoch:  0  test acc:  0.1244
# accuracy for Node:  5   is:  0.24   at epoch:  0  test acc:  0.1152
# accuracy for Node:  6   is:  0.18   at epoch:  0  test acc:  0.1209
# accuracy for Node:  7   is:  0.24   at epoch:  0  test acc:  0.1792
# accuracy for Node:  8   is:  0.28   at epoch:  0  test acc:  0.1308
# accuracy for Node:  9   is:  0.28   at epoch:  0  test acc:  0.1742
# accuracy for Node:  10   is:  0.26   at epoch:  0  test acc:  0.1309
# accuracy for Node:  11   is:  0.18   at epoch:  0  test acc:  0.0814
# accuracy for Node:  12   is:  0.24   at epoch:  0  test acc:  0.1851
# accuracy for Node:  13   is:  0.42   at epoch:  0  test acc:  0.2145
# accuracy for Node:  14   is:  0.3   at epoch:  0  test acc:  0.1286
# accuracy for Node:  0   is:  0.9   at epoch:  50  test acc:  0.7978
# accuracy for Node:  1   is:  0.84   at epoch:  50  test acc:  0.8026
# accuracy for Node:  2   is:  0.8   at epoch:  50  test acc:  0.7807
# accuracy for Node:  3   is:  0.82   at epoch:  50  test acc:  0.7762
# accuracy for Node:  4   is:  0.84   at epoch:  50  test acc:  0.7945
# accuracy for Node:  5   is:  0.86   at epoch:  50  test acc:  0.8251
# accuracy for Node:  6   is:  0.82   at epoch:  50  test acc:  0.7922
# accuracy for Node:  7   is:  0.86   at epoch:  50  test acc:  0.7885
# accuracy for Node:  8   is:  0.88   at epoch:  50  test acc:  0.8064
# accuracy for Node:  9   is:  0.72   at epoch:  50  test acc:  0.7993
# accuracy for Node:  10   is:  0.84   at epoch:  50  test acc:  0.8144
# accuracy for Node:  11   is:  0.82   at epoch:  50  test acc:  0.7735
# accuracy for Node:  12   is:  0.86   at epoch:  50  test acc:  0.8057
# accuracy for Node:  13   is:  0.78   at epoch:  50  test acc:  0.7969
# accuracy for Node:  14   is:  0.86   at epoch:  50  test acc:  0.8154
# accuracy for Node:  0   is:  0.88   at epoch:  100  test acc:  0.8455
# accuracy for Node:  1   is:  0.94   at epoch:  100  test acc:  0.8436
# accuracy for Node:  2   is:  0.82   at epoch:  100  test acc:  0.858
# accuracy for Node:  3   is:  0.88   at epoch:  100  test acc:  0.8391
# accuracy for Node:  4   is:  0.94   at epoch:  100  test acc:  0.8457
# accuracy for Node:  5   is:  0.84   at epoch:  100  test acc:  0.8528
# accuracy for Node:  6   is:  0.86   at epoch:  100  test acc:  0.8595
# accuracy for Node:  7   is:  0.96   at epoch:  100  test acc:  0.8391
# accuracy for Node:  8   is:  0.9   at epoch:  100  test acc:  0.8341
# accuracy for Node:  9   is:  0.88   at epoch:  100  test acc:  0.8414
# accuracy for Node:  10   is:  0.82   at epoch:  100  test acc:  0.8625
# accuracy for Node:  11   is:  0.94   at epoch:  100  test acc:  0.8642
# accuracy for Node:  12   is:  0.86   at epoch:  100  test acc:  0.8518
# accuracy for Node:  13   is:  0.94   at epoch:  100  test acc:  0.8554
# accuracy for Node:  14   is:  0.9   at epoch:  100  test acc:  0.8595
# Final accuracy on test set:
# 0  has accuracy:  0.8711
# 1  has accuracy:  0.8657
# 2  has accuracy:  0.8792
# 3  has accuracy:  0.8582
# 4  has accuracy:  0.8622
# 5  has accuracy:  0.8569
# 6  has accuracy:  0.8485
# 7  has accuracy:  0.873
# 8  has accuracy:  0.8744
# 9  has accuracy:  0.8785
# 10  has accuracy:  0.8598
# 11  has accuracy:  0.8825
# 12  has accuracy:  0.8647
# 13  has accuracy:  0.8814
# 14  has accuracy:  0.8732
# accuracy for Node:  0   is:  0.6   at epoch:  0  test acc:  0.2574
# accuracy for Node:  1   is:  0.54   at epoch:  0  test acc:  0.3005
# accuracy for Node:  2   is:  0.5   at epoch:  0  test acc:  0.2598
# accuracy for Node:  3   is:  0.64   at epoch:  0  test acc:  0.2356
# accuracy for Node:  0   is:  1.0   at epoch:  50  test acc:  0.8745
# accuracy for Node:  1   is:  0.96   at epoch:  50  test acc:  0.882
# accuracy for Node:  2   is:  1.0   at epoch:  50  test acc:  0.882
# accuracy for Node:  3   is:  1.0   at epoch:  50  test acc:  0.8724
# accuracy for Node:  0   is:  0.94   at epoch:  100  test acc:  0.9009
# accuracy for Node:  1   is:  1.0   at epoch:  100  test acc:  0.9023
# accuracy for Node:  2   is:  1.0   at epoch:  100  test acc:  0.9099
# accuracy for Node:  3   is:  1.0   at epoch:  100  test acc:  0.8943
# accuracy for Node:  0   is:  1.0   at epoch:  150  test acc:  0.9087
# accuracy for Node:  1   is:  1.0   at epoch:  150  test acc:  0.9174
# accuracy for Node:  2   is:  1.0   at epoch:  150  test acc:  0.9048
# accuracy for Node:  3   is:  1.0   at epoch:  150  test acc:  0.9134
# accuracy for Node:  0   is:  1.0   at epoch:  200  test acc:  0.923
# accuracy for Node:  1   is:  1.0   at epoch:  200  test acc:  0.9244
# accuracy for Node:  2   is:  1.0   at epoch:  200  test acc:  0.9199
# accuracy for Node:  3   is:  1.0   at epoch:  200  test acc:  0.9276
# accuracy for Node:  0   is:  1.0   at epoch:  250  test acc:  0.9262
# accuracy for Node:  1   is:  1.0   at epoch:  250  test acc:  0.9169
# accuracy for Node:  2   is:  1.0   at epoch:  250  test acc:  0.9152
# accuracy for Node:  3   is:  0.98   at epoch:  250  test acc:  0.9189
# accuracy for Node:  0   is:  1.0   at epoch:  300  test acc:  0.9209
# accuracy for Node:  1   is:  0.98   at epoch:  300  test acc:  0.9238
# accuracy for Node:  2   is:  1.0   at epoch:  300  test acc:  0.9278
# accuracy for Node:  3   is:  1.0   at epoch:  300  test acc:  0.9189
# accuracy for Node:  0   is:  1.0   at epoch:  350  test acc:  0.9338
# accuracy for Node:  1   is:  1.0   at epoch:  350  test acc:  0.9338
# accuracy for Node:  2   is:  1.0   at epoch:  350  test acc:  0.9307
# accuracy for Node:  3   is:  1.0   at epoch:  350  test acc:  0.9319
# accuracy for Node:  0   is:  1.0   at epoch:  400  test acc:  0.9406
# accuracy for Node:  1   is:  1.0   at epoch:  400  test acc:  0.9417
# accuracy for Node:  2   is:  0.98   at epoch:  400  test acc:  0.9303
# accuracy for Node:  3   is:  1.0   at epoch:  400  test acc:  0.9375
# accuracy for Node:  0   is:  1.0   at epoch:  450  test acc:  0.943
# accuracy for Node:  1   is:  1.0   at epoch:  450  test acc:  0.9422
# accuracy for Node:  2   is:  0.98   at epoch:  450  test acc:  0.9229
# accuracy for Node:  3   is:  1.0   at epoch:  450  test acc:  0.9395
# Final accuracy on test set:
# 0  has accuracy:  0.9452
# 1  has accuracy:  0.9391
# 2  has accuracy:  0.9439
# 3  has accuracy:  0.9459
# accuracy for Node:  0   is:  0.6   at epoch:  0  test acc:  0.2433
# accuracy for Node:  1   is:  0.54   at epoch:  0  test acc:  0.2698
# accuracy for Node:  2   is:  0.62   at epoch:  0  test acc:  0.2247
# accuracy for Node:  3   is:  0.6   at epoch:  0  test acc:  0.2248
# accuracy for Node:  4   is:  0.64   at epoch:  0  test acc:  0.3425
# accuracy for Node:  0   is:  0.98   at epoch:  50  test acc:  0.8738
# accuracy for Node:  1   is:  0.98   at epoch:  50  test acc:  0.8663
# accuracy for Node:  2   is:  1.0   at epoch:  50  test acc:  0.8836
# accuracy for Node:  3   is:  1.0   at epoch:  50  test acc:  0.8669
# accuracy for Node:  4   is:  0.98   at epoch:  50  test acc:  0.8757
# accuracy for Node:  0   is:  1.0   at epoch:  100  test acc:  0.8762
# accuracy for Node:  1   is:  1.0   at epoch:  100  test acc:  0.9073
# accuracy for Node:  2   is:  1.0   at epoch:  100  test acc:  0.8956
# accuracy for Node:  3   is:  1.0   at epoch:  100  test acc:  0.8971
# accuracy for Node:  4   is:  1.0   at epoch:  100  test acc:  0.9102
# accuracy for Node:  0   is:  1.0   at epoch:  150  test acc:  0.9058
# accuracy for Node:  1   is:  1.0   at epoch:  150  test acc:  0.9175
# accuracy for Node:  2   is:  0.98   at epoch:  150  test acc:  0.904
# accuracy for Node:  3   is:  1.0   at epoch:  150  test acc:  0.9083
# accuracy for Node:  4   is:  1.0   at epoch:  150  test acc:  0.9154
# accuracy for Node:  0   is:  0.96   at epoch:  200  test acc:  0.9191
# accuracy for Node:  1   is:  1.0   at epoch:  200  test acc:  0.9189
# accuracy for Node:  2   is:  1.0   at epoch:  200  test acc:  0.9289
# accuracy for Node:  3   is:  1.0   at epoch:  200  test acc:  0.92
# accuracy for Node:  4   is:  1.0   at epoch:  200  test acc:  0.9292
# accuracy for Node:  0   is:  1.0   at epoch:  250  test acc:  0.925
# accuracy for Node:  1   is:  1.0   at epoch:  250  test acc:  0.9277
# accuracy for Node:  2   is:  1.0   at epoch:  250  test acc:  0.9283
# accuracy for Node:  3   is:  1.0   at epoch:  250  test acc:  0.9312
# accuracy for Node:  4   is:  1.0   at epoch:  250  test acc:  0.9277
# accuracy for Node:  0   is:  1.0   at epoch:  300  test acc:  0.935
# accuracy for Node:  1   is:  1.0   at epoch:  300  test acc:  0.9089
# accuracy for Node:  2   is:  1.0   at epoch:  300  test acc:  0.9405
# accuracy for Node:  3   is:  1.0   at epoch:  300  test acc:  0.9345
# accuracy for Node:  4   is:  1.0   at epoch:  300  test acc:  0.9381
# accuracy for Node:  0   is:  1.0   at epoch:  350  test acc:  0.9445
# accuracy for Node:  1   is:  1.0   at epoch:  350  test acc:  0.9352
# accuracy for Node:  2   is:  1.0   at epoch:  350  test acc:  0.9333
# accuracy for Node:  3   is:  1.0   at epoch:  350  test acc:  0.9357
# accuracy for Node:  4   is:  1.0   at epoch:  350  test acc:  0.9441
# Final accuracy on test set:
# 0  has accuracy:  0.9446
# 1  has accuracy:  0.9474
# 2  has accuracy:  0.9443
# 3  has accuracy:  0.9422
# 4  has accuracy:  0.9453
# accuracy for Node:  0   is:  0.62   at epoch:  0  test acc:  0.285
# accuracy for Node:  1   is:  0.74   at epoch:  0  test acc:  0.278
# accuracy for Node:  2   is:  0.6   at epoch:  0  test acc:  0.2985
# accuracy for Node:  3   is:  0.7   at epoch:  0  test acc:  0.2988
# accuracy for Node:  4   is:  0.66   at epoch:  0  test acc:  0.3149
# accuracy for Node:  5   is:  0.6   at epoch:  0  test acc:  0.3622
# accuracy for Node:  0   is:  1.0   at epoch:  50  test acc:  0.8905
# accuracy for Node:  1   is:  1.0   at epoch:  50  test acc:  0.8778
# accuracy for Node:  2   is:  1.0   at epoch:  50  test acc:  0.8893
# accuracy for Node:  3   is:  1.0   at epoch:  50  test acc:  0.8922
# accuracy for Node:  4   is:  1.0   at epoch:  50  test acc:  0.8722
# accuracy for Node:  5   is:  1.0   at epoch:  50  test acc:  0.879
# accuracy for Node:  0   is:  1.0   at epoch:  100  test acc:  0.8941
# accuracy for Node:  1   is:  1.0   at epoch:  100  test acc:  0.8933
# accuracy for Node:  2   is:  1.0   at epoch:  100  test acc:  0.9074
# accuracy for Node:  3   is:  1.0   at epoch:  100  test acc:  0.9061
# accuracy for Node:  4   is:  1.0   at epoch:  100  test acc:  0.9132
# accuracy for Node:  5   is:  1.0   at epoch:  100  test acc:  0.9012
# accuracy for Node:  0   is:  1.0   at epoch:  150  test acc:  0.9236
# accuracy for Node:  1   is:  1.0   at epoch:  150  test acc:  0.9212
# accuracy for Node:  2   is:  1.0   at epoch:  150  test acc:  0.9015
# accuracy for Node:  3   is:  1.0   at epoch:  150  test acc:  0.911
# accuracy for Node:  4   is:  1.0   at epoch:  150  test acc:  0.92
# accuracy for Node:  5   is:  1.0   at epoch:  150  test acc:  0.9147
# accuracy for Node:  0   is:  1.0   at epoch:  200  test acc:  0.9383
# accuracy for Node:  1   is:  1.0   at epoch:  200  test acc:  0.929
# accuracy for Node:  2   is:  1.0   at epoch:  200  test acc:  0.9283
# accuracy for Node:  3   is:  1.0   at epoch:  200  test acc:  0.9291
# accuracy for Node:  4   is:  1.0   at epoch:  200  test acc:  0.9296
# accuracy for Node:  5   is:  1.0   at epoch:  200  test acc:  0.9203
# accuracy for Node:  0   is:  1.0   at epoch:  250  test acc:  0.9311
# accuracy for Node:  1   is:  1.0   at epoch:  250  test acc:  0.9319
# accuracy for Node:  2   is:  1.0   at epoch:  250  test acc:  0.9316
# accuracy for Node:  3   is:  0.98   at epoch:  250  test acc:  0.9265
# ...
# accuracy for Node:  5   is:  0.98   at epoch:  100  test acc:  0.8706
# accuracy for Node:  6   is:  0.94   at epoch:  100  test acc:  0.8865
# accuracy for Node:  7   is:  0.98   at epoch:  100  test acc:  0.8782
# accuracy for Node:  8   is:  0.98   at epoch:  100  test acc:  0.8918
# accuracy for Node:  9   is:  0.9   at epoch:  100  test acc:  0.8814
# accuracy for Node:  10   is:  0.98   at epoch:  100  test acc:  0.8634
# accuracy for Node:  0   is:  0.98   at epoch:  150  test acc:  0.8969
# accuracy for Node:  1   is:  0.98   at epoch:  150  test acc:  0.8976
# accuracy for Node:  2   is:  1.0   at epoch:  150  test acc:  0.8997
# accuracy for Node:  3   is:  1.0   at epoch:  150  test acc:  0.9052
# accuracy for Node:  4   is:  0.98   at epoch:  150  test acc:  0.9059
# accuracy for Node:  5   is:  1.0   at epoch:  150  test acc:  0.903
# accuracy for Node:  6   is:  0.96   at epoch:  150  test acc:  0.8948
# accuracy for Node:  7   is:  1.0   at epoch:  150  test acc:  0.893
# accuracy for Node:  8   is:  0.94   at epoch:  150  test acc:  0.8917
# accuracy for Node:  9   is:  1.0   at epoch:  150  test acc:  0.8597
# accuracy for Node:  10   is:  1.0   at epoch:  150  test acc:  0.8854
# Final accuracy on test set:
# 0  has accuracy:  0.9065
# 1  has accuracy:  0.9014
# 2  has accuracy:  0.9028
# 3  has accuracy:  0.9129
# 4  has accuracy:  0.8998
# 5  has accuracy:  0.8617
# 6  has accuracy:  0.8921
# 7  has accuracy:  0.8932
# 8  has accuracy:  0.9109
# 9  has accuracy:  0.8968
# 10  has accuracy:  0.9087
# accuracy for Node:  0   is:  0.44   at epoch:  0  test acc:  0.2776
# accuracy for Node:  1   is:  0.6   at epoch:  0  test acc:  0.2375
# accuracy for Node:  2   is:  0.38   at epoch:  0  test acc:  0.1368
# accuracy for Node:  3   is:  0.28   at epoch:  0  test acc:  0.1645
# accuracy for Node:  4   is:  0.34   at epoch:  0  test acc:  0.1957
# accuracy for Node:  5   is:  0.38   at epoch:  0  test acc:  0.2049
# accuracy for Node:  6   is:  0.26   at epoch:  0  test acc:  0.1331
# accuracy for Node:  7   is:  0.46   at epoch:  0  test acc:  0.2409
# accuracy for Node:  8   is:  0.54   at epoch:  0  test acc:  0.2752
# accuracy for Node:  9   is:  0.3   at epoch:  0  test acc:  0.1871
# accuracy for Node:  10   is:  0.46   at epoch:  0  test acc:  0.2123
# accuracy for Node:  11   is:  0.42   at epoch:  0  test acc:  0.225
# accuracy for Node:  0   is:  0.98   at epoch:  50  test acc:  0.8602
# accuracy for Node:  1   is:  0.96   at epoch:  50  test acc:  0.8704
# accuracy for Node:  2   is:  0.96   at epoch:  50  test acc:  0.8537
# accuracy for Node:  3   is:  0.9   at epoch:  50  test acc:  0.8276
# accuracy for Node:  4   is:  1.0   at epoch:  50  test acc:  0.87
# accuracy for Node:  5   is:  0.9   at epoch:  50  test acc:  0.866
# accuracy for Node:  6   is:  1.0   at epoch:  50  test acc:  0.8771
# accuracy for Node:  7   is:  0.98   at epoch:  50  test acc:  0.8804
# accuracy for Node:  8   is:  0.92   at epoch:  50  test acc:  0.8369
# accuracy for Node:  9   is:  0.96   at epoch:  50  test acc:  0.8472
# accuracy for Node:  10   is:  0.98   at epoch:  50  test acc:  0.8643
# accuracy for Node:  11   is:  1.0   at epoch:  50  test acc:  0.8707
# accuracy for Node:  0   is:  0.9   at epoch:  100  test acc:  0.8104
# accuracy for Node:  1   is:  1.0   at epoch:  100  test acc:  0.8727
# accuracy for Node:  2   is:  0.98   at epoch:  100  test acc:  0.8459
# accuracy for Node:  3   is:  1.0   at epoch:  100  test acc:  0.8944
# accuracy for Node:  4   is:  0.96   at epoch:  100  test acc:  0.8806
# accuracy for Node:  5   is:  0.98   at epoch:  100  test acc:  0.8758
# accuracy for Node:  6   is:  1.0   at epoch:  100  test acc:  0.8592
# accuracy for Node:  7   is:  1.0   at epoch:  100  test acc:  0.8965
# accuracy for Node:  8   is:  0.98   at epoch:  100  test acc:  0.8827
# accuracy for Node:  9   is:  1.0   at epoch:  100  test acc:  0.8926
# accuracy for Node:  10   is:  1.0   at epoch:  100  test acc:  0.8857
# accuracy for Node:  11   is:  0.98   at epoch:  100  test acc:  0.8958
# accuracy for Node:  0   is:  1.0   at epoch:  150  test acc:  0.8962
# accuracy for Node:  1   is:  1.0   at epoch:  150  test acc:  0.8987
# accuracy for Node:  2   is:  0.96   at epoch:  150  test acc:  0.886
# accuracy for Node:  3   is:  1.0   at epoch:  150  test acc:  0.8956
# accuracy for Node:  4   is:  0.96   at epoch:  150  test acc:  0.8918
# accuracy for Node:  5   is:  0.98   at epoch:  150  test acc:  0.8945
# accuracy for Node:  6   is:  1.0   at epoch:  150  test acc:  0.8961
# accuracy for Node:  7   is:  0.98   at epoch:  150  test acc:  0.9188
# accuracy for Node:  8   is:  0.98   at epoch:  150  test acc:  0.8961
# accuracy for Node:  9   is:  1.0   at epoch:  150  test acc:  0.8902
# accuracy for Node:  10   is:  0.98   at epoch:  150  test acc:  0.9005
# accuracy for Node:  11   is:  0.94   at epoch:  150  test acc:  0.8869
# Final accuracy on test set:
# 0  has accuracy:  0.9014
# 1  has accuracy:  0.8893
# 2  has accuracy:  0.8987
# 3  has accuracy:  0.9071
# 4  has accuracy:  0.8992
# 5  has accuracy:  0.8999
# 6  has accuracy:  0.8977
# 7  has accuracy:  0.894
# 8  has accuracy:  0.896
# 9  has accuracy:  0.9014
# 10  has accuracy:  0.8981
# 11  has accuracy:  0.8862
# accuracy for Node:  0   is:  0.48   at epoch:  0  test acc:  0.1894
# accuracy for Node:  1   is:  0.38   at epoch:  0  test acc:  0.2034
# accuracy for Node:  2   is:  0.36   at epoch:  0  test acc:  0.1571
# accuracy for Node:  3   is:  0.42   at epoch:  0  test acc:  0.2482
# accuracy for Node:  4   is:  0.5   at epoch:  0  test acc:  0.1798
# accuracy for Node:  5   is:  0.42   at epoch:  0  test acc:  0.1658
# accuracy for Node:  6   is:  0.42   at epoch:  0  test acc:  0.2334
# accuracy for Node:  7   is:  0.42   at epoch:  0  test acc:  0.1931
# accuracy for Node:  8   is:  0.34   at epoch:  0  test acc:  0.2103
# accuracy for Node:  9   is:  0.44   at epoch:  0  test acc:  0.241
# accuracy for Node:  10   is:  0.46   at epoch:  0  test acc:  0.2023
# accuracy for Node:  11   is:  0.52   at epoch:  0  test acc:  0.2446
# accuracy for Node:  12   is:  0.46   at epoch:  0  test acc:  0.1239
# accuracy for Node:  0   is:  1.0   at epoch:  50  test acc:  0.869
# accuracy for Node:  1   is:  0.82   at epoch:  50  test acc:  0.7201
# accuracy for Node:  2   is:  0.94   at epoch:  50  test acc:  0.8599
# accuracy for Node:  3   is:  0.86   at epoch:  50  test acc:  0.8514
# accuracy for Node:  4   is:  0.96   at epoch:  50  test acc:  0.8398
# accuracy for Node:  5   is:  0.98   at epoch:  50  test acc:  0.8552
# accuracy for Node:  6   is:  0.96   at epoch:  50  test acc:  0.8175
# accuracy for Node:  7   is:  0.92   at epoch:  50  test acc:  0.8347
# accuracy for Node:  8   is:  0.96   at epoch:  50  test acc:  0.8777
# accuracy for Node:  9   is:  0.96   at epoch:  50  test acc:  0.8596
# accuracy for Node:  10   is:  1.0   at epoch:  50  test acc:  0.8477
# accuracy for Node:  11   is:  1.0   at epoch:  50  test acc:  0.8704
# accuracy for Node:  12   is:  1.0   at epoch:  50  test acc:  0.8631
# accuracy for Node:  0   is:  1.0   at epoch:  100  test acc:  0.8711
# accuracy for Node:  1   is:  0.94   at epoch:  100  test acc:  0.885
# accuracy for Node:  2   is:  1.0   at epoch:  100  test acc:  0.8887
# accuracy for Node:  3   is:  0.98   at epoch:  100  test acc:  0.8775
# accuracy for Node:  4   is:  0.94   at epoch:  100  test acc:  0.8668
# accuracy for Node:  5   is:  0.98   at epoch:  100  test acc:  0.886
# accuracy for Node:  6   is:  0.96   at epoch:  100  test acc:  0.8584
# accuracy for Node:  7   is:  1.0   at epoch:  100  test acc:  0.875
# accuracy for Node:  8   is:  0.98   at epoch:  100  test acc:  0.8927
# accuracy for Node:  9   is:  0.96   at epoch:  100  test acc:  0.869
# accuracy for Node:  10   is:  0.98   at epoch:  100  test acc:  0.8809
# accuracy for Node:  11   is:  0.98   at epoch:  100  test acc:  0.8965
# accuracy for Node:  12   is:  0.96   at epoch:  100  test acc:  0.8659
# accuracy for Node:  0   is:  1.0   at epoch:  150  test acc:  0.8999
# accuracy for Node:  1   is:  1.0   at epoch:  150  test acc:  0.9005
# accuracy for Node:  2   is:  0.98   at epoch:  150  test acc:  0.9062
# accuracy for Node:  3   is:  0.98   at epoch:  150  test acc:  0.8996
# accuracy for Node:  4   is:  0.98   at epoch:  150  test acc:  0.9031
# accuracy for Node:  5   is:  0.96   at epoch:  150  test acc:  0.8917
# accuracy for Node:  6   is:  1.0   at epoch:  150  test acc:  0.8965
# accuracy for Node:  7   is:  0.98   at epoch:  150  test acc:  0.9047
# accuracy for Node:  8   is:  1.0   at epoch:  150  test acc:  0.8913
# accuracy for Node:  9   is:  0.98   at epoch:  150  test acc:  0.8957
# accuracy for Node:  10   is:  1.0   at epoch:  150  test acc:  0.8945
# accuracy for Node:  11   is:  0.98   at epoch:  150  test acc:  0.8857
# accuracy for Node:  12   is:  1.0   at epoch:  150  test acc:  0.8866
# Final accuracy on test set:
# 0  has accuracy:  0.902
# 1  has accuracy:  0.8964
# 2  has accuracy:  0.9072
# 3  has accuracy:  0.8935
# 4  has accuracy:  0.8863
# 5  has accuracy:  0.8959
# 6  has accuracy:  0.8872
# 7  has accuracy:  0.8781
# 8  has accuracy:  0.8959
# 9  has accuracy:  0.905
# 10  has accuracy:  0.8783
# 11  has accuracy:  0.8812
# 12  has accuracy:  0.9033
# accuracy for Node:  0   is:  0.42   at epoch:  0  test acc:  0.2541
# accuracy for Node:  1   is:  0.36   at epoch:  0  test acc:  0.2038
# accuracy for Node:  2   is:  0.48   at epoch:  0  test acc:  0.2156
# accuracy for Node:  3   is:  0.36   at epoch:  0  test acc:  0.1485
# accuracy for Node:  4   is:  0.44   at epoch:  0  test acc:  0.2048
# accuracy for Node:  5   is:  0.48   at epoch:  0  test acc:  0.192
# accuracy for Node:  6   is:  0.54   at epoch:  0  test acc:  0.1797
# accuracy for Node:  7   is:  0.4   at epoch:  0  test acc:  0.2303
# accuracy for Node:  8   is:  0.46   at epoch:  0  test acc:  0.1932
# accuracy for Node:  9   is:  0.44   at epoch:  0  test acc:  0.23
# accuracy for Node:  10   is:  0.48   at epoch:  0  test acc:  0.2226
# accuracy for Node:  11   is:  0.4   at epoch:  0  test acc:  0.1744
# accuracy for Node:  12   is:  0.34   at epoch:  0  test acc:  0.1549
# accuracy for Node:  13   is:  0.42   at epoch:  0  test acc:  0.2055
# accuracy for Node:  0   is:  0.94   at epoch:  50  test acc:  0.862
# accuracy for Node:  1   is:  0.94   at epoch:  50  test acc:  0.8585
# accuracy for Node:  2   is:  0.98   at epoch:  50  test acc:  0.8771
# accuracy for Node:  3   is:  0.86   at epoch:  50  test acc:  0.8495
# accuracy for Node:  4   is:  0.98   at epoch:  50  test acc:  0.8613
# accuracy for Node:  5   is:  0.98   at epoch:  50  test acc:  0.8542
# accuracy for Node:  6   is:  0.9   at epoch:  50  test acc:  0.864
# accuracy for Node:  7   is:  0.96   at epoch:  50  test acc:  0.8628
# accuracy for Node:  8   is:  0.98   at epoch:  50  test acc:  0.8722
# accuracy for Node:  9   is:  0.96   at epoch:  50  test acc:  0.8417
# accuracy for Node:  10   is:  0.98   at epoch:  50  test acc:  0.8669
# accuracy for Node:  11   is:  0.98   at epoch:  50  test acc:  0.8659
# accuracy for Node:  12   is:  0.9   at epoch:  50  test acc:  0.8456
# accuracy for Node:  13   is:  0.96   at epoch:  50  test acc:  0.8568
# accuracy for Node:  0   is:  0.94   at epoch:  100  test acc:  0.8634
# accuracy for Node:  1   is:  1.0   at epoch:  100  test acc:  0.8584
# accuracy for Node:  2   is:  0.98   at epoch:  100  test acc:  0.8992
# accuracy for Node:  3   is:  1.0   at epoch:  100  test acc:  0.8906
# accuracy for Node:  4   is:  0.98   at epoch:  100  test acc:  0.8775
# accuracy for Node:  5   is:  0.98   at epoch:  100  test acc:  0.8886
# accuracy for Node:  6   is:  0.98   at epoch:  100  test acc:  0.8864
# accuracy for Node:  7   is:  0.98   at epoch:  100  test acc:  0.8824
# accuracy for Node:  8   is:  0.98   at epoch:  100  test acc:  0.8602
# accuracy for Node:  9   is:  0.96   at epoch:  100  test acc:  0.868
# accuracy for Node:  10   is:  1.0   at epoch:  100  test acc:  0.8904
# accuracy for Node:  11   is:  1.0   at epoch:  100  test acc:  0.8784
# accuracy for Node:  12   is:  0.98   at epoch:  100  test acc:  0.8628
# accuracy for Node:  13   is:  0.96   at epoch:  100  test acc:  0.892
# Final accuracy on test set:
# 0  has accuracy:  0.8919
# 1  has accuracy:  0.8811
# 2  has accuracy:  0.8811
# 3  has accuracy:  0.8986
# 4  has accuracy:  0.8997
# 5  has accuracy:  0.8947
# 6  has accuracy:  0.8945
# 7  has accuracy:  0.9022
# 8  has accuracy:  0.8751
# 9  has accuracy:  0.8962
# 10  has accuracy:  0.8939
# 11  has accuracy:  0.9049
# 12  has accuracy:  0.8953
# 13  has accuracy:  0.9071
# accuracy for Node:  0   is:  0.44   at epoch:  0  test acc:  0.1979
# accuracy for Node:  1   is:  0.2   at epoch:  0  test acc:  0.1508
# accuracy for Node:  2   is:  0.5   at epoch:  0  test acc:  0.2281
# accuracy for Node:  3   is:  0.2   at epoch:  0  test acc:  0.1623
# accuracy for Node:  4   is:  0.4   at epoch:  0  test acc:  0.1858
# accuracy for Node:  5   is:  0.46   at epoch:  0  test acc:  0.2427
# accuracy for Node:  6   is:  0.52   at epoch:  0  test acc:  0.2787
# accuracy for Node:  7   is:  0.38   at epoch:  0  test acc:  0.2027
# accuracy for Node:  8   is:  0.42   at epoch:  0  test acc:  0.1844
# accuracy for Node:  9   is:  0.52   at epoch:  0  test acc:  0.2554
# accuracy for Node:  10   is:  0.56   at epoch:  0  test acc:  0.2399
# accuracy for Node:  11   is:  0.4   at epoch:  0  test acc:  0.2267
# accuracy for Node:  12   is:  0.38   at epoch:  0  test acc:  0.1578
# accuracy for Node:  13   is:  0.4   at epoch:  0  test acc:  0.2284
# accuracy for Node:  14   is:  0.4   at epoch:  0  test acc:  0.1701
# accuracy for Node:  0   is:  1.0   at epoch:  50  test acc:  0.865
# accuracy for Node:  1   is:  0.92   at epoch:  50  test acc:  0.8415
# accuracy for Node:  2   is:  0.94   at epoch:  50  test acc:  0.8523
# accuracy for Node:  3   is:  1.0   at epoch:  50  test acc:  0.8428
# accuracy for Node:  4   is:  0.94   at epoch:  50  test acc:  0.8744
# accuracy for Node:  5   is:  1.0   at epoch:  50  test acc:  0.8735
# accuracy for Node:  6   is:  0.9   at epoch:  50  test acc:  0.8712
# accuracy for Node:  7   is:  1.0   at epoch:  50  test acc:  0.868
# accuracy for Node:  8   is:  1.0   at epoch:  50  test acc:  0.8542
# accuracy for Node:  9   is:  0.98   at epoch:  50  test acc:  0.8659
# accuracy for Node:  10   is:  0.94   at epoch:  50  test acc:  0.8424
# accuracy for Node:  11   is:  0.94   at epoch:  50  test acc:  0.844
# accuracy for Node:  12   is:  0.94   at epoch:  50  test acc:  0.8602
# accuracy for Node:  13   is:  1.0   at epoch:  50  test acc:  0.8758
# accuracy for Node:  14   is:  0.98   at epoch:  50  test acc:  0.8599
# accuracy for Node:  0   is:  1.0   at epoch:  100  test acc:  0.8786
# accuracy for Node:  1   is:  0.98   at epoch:  100  test acc:  0.8511
# accuracy for Node:  2   is:  0.94   at epoch:  100  test acc:  0.8885
# accuracy for Node:  3   is:  0.98   at epoch:  100  test acc:  0.8929
# accuracy for Node:  4   is:  0.98   at epoch:  100  test acc:  0.8879
# accuracy for Node:  5   is:  1.0   at epoch:  100  test acc:  0.8826
# accuracy for Node:  6   is:  1.0   at epoch:  100  test acc:  0.8671
# accuracy for Node:  7   is:  0.98   at epoch:  100  test acc:  0.8686
# accuracy for Node:  8   is:  1.0   at epoch:  100  test acc:  0.8823
# accuracy for Node:  9   is:  1.0   at epoch:  100  test acc:  0.8894
# accuracy for Node:  10   is:  0.96   at epoch:  100  test acc:  0.8684
# accuracy for Node:  11   is:  1.0   at epoch:  100  test acc:  0.8917
# accuracy for Node:  12   is:  1.0   at epoch:  100  test acc:  0.8687
# accuracy for Node:  13   is:  1.0   at epoch:  100  test acc:  0.8959
# accuracy for Node:  14   is:  1.0   at epoch:  100  test acc:  0.8828
# Final accuracy on test set:
# 0  has accuracy:  0.899
# 1  has accuracy:  0.9014
# 2  has accuracy:  0.8794
# 3  has accuracy:  0.8763
# 4  has accuracy:  0.8991
# 5  has accuracy:  0.8944
# 6  has accuracy:  0.8951
# 7  has accuracy:  0.8994
# 8  has accuracy:  0.8808
# 9  has accuracy:  0.892
# 10  has accuracy:  0.8718
# 11  has accuracy:  0.8988
# 12  has accuracy:  0.8848
# 13  has accuracy:  0.8977
# 14  has accuracy:  0.9025
# [<matplotlib.lines.Line2D at 0x7fdf678fab70>,
#  <matplotlib.lines.Line2D at 0x7fdf678fa320>,
#  <matplotlib.lines.Line2D at 0x7fdf6729d470>]
